# %% [markdown]
# # Laboratory Session 2

# %% [markdown]
# ### Problem 1:

# %%
import matplotlib.pyplot as plt
years = list(range(1960, 2021, 10))
xgdp = [400.2, 643.3, 1175.9, 3062.5, 6079.6, 11289.7, 10658.3]
ygdp = [336.0, 472.0, 1028.0, 2092.0, 5131.0, 7689.0, 14147.0]
zgdp = [1307.0, 1158.0, 1191.0, 3140.0, 9023.0, 15502.0, 22218.0]

# %%
plt.plot(years, xgdp)
plt.plot(years, ygdp)
plt.plot(years, zgdp)
plt.title('Nominal GDP of 3 Countries: X, Y, Z')
plt.xlabel('Year')
plt.ylabel('Billions of $')
plt.grid(True)
plt.show()

# %%
movies = ["Annie Hall", "Ben-Hur", "Casablanca", "Gandhi", "West Side Story"]
num_oscars = [5, 11, 3, 8, 10]
xs = range(len(movies))

# %%
plt.bar(xs, num_oscars)
plt.xticks(xs, movies)
plt.ylabel("Numbers of Academy Awards")
plt.title("Movies")
plt.show()

# %% [markdown]
# ### Problem 2:

# %%
import numpy as np
import matplotlib.pyplot as plt
years = np.arange(1960, 2021, 10)
xgdp = [400.2, 643.3, 1175.9, 3062.5, 6079.6, 11289.7, 10658.3]
ygdp = [336.0, 472.0, 1028.0, 2092.0, 5131.0, 7689.0, 14147.0]
zgdp = [1307.0, 1158.0, 1191.0, 3140.0, 9023.0, 15502.0, 22218.0]

# %%
plt.bar(years-2.5, xgdp, width=2.5)
plt.bar(years, ygdp, width=2.5)
plt.bar(years+2.5, zgdp, width=2.5)
plt.title('Nominal GDP of 3 Countries: X, Y, Z')
plt.xlabel('Year')
plt.ylabel('Billions of $')
plt.show()

# %% [markdown]
# ### Problem 3:

# %%
import matplotlib.pyplot as plt
countries = ['X', 'Y', 'Z', 'W']
exportrate = [50, 24, 18, 8]

# %%
plt.pie(exportrate, labels=countries, startangle=90)
plt.title("Export Rate")
plt.show()
